# %%
from PIL import Image
from scipy.linalg import svd
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_image_feature(s, k):
    # 对s保留前k个特征值
    s_temp = np.zeros(s.shape[0])
    s_temp[0:k] = s[0:k]
    s = s_temp * np.identity(s.shape[0])
    # 用新的s及p，q重构矩阵
    temp = np.dot(p, s)
    temp = np.dot(temp, q)
    plt.imshow(temp, cmap=plt.cm.gray, interpolation='nearest')
    plt.show()
    print(A-temp)

# %%
# 加载图片并将图片灰度化后转化为矩阵形式
image = Image.open('./husky.jpg').convert('L')
A = np.array(image)
# 原图像灰度化效果
plt.imshow(A, cmap=plt.cm.gray, interpolation='nearest')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# 对矩阵进行奇异值分解得p,s,q
p, s, q = svd(A, full_matrices=False)
# 愿图像特征值数量
n = A.shape[1]
# 奇异值数量为原有的1%
get_image_feature(s, int(0.01*n))
# Out:
# [[ 40.04458275  17.39496985   6.48512214 ... -13.34747254 -12.324268
#   -10.594901  ]
#  [ 33.14852851  15.54945395   8.81127931 ... -16.19323445 -14.36294877
#   -12.65852346]
#  [ 29.18107687  19.73786619  17.29382933 ... -14.00897775 -11.40652207
#    -8.70458066]
#  ...
#  [  1.35284693   1.73958276  -0.56101884 ...   4.56142087   5.6777516
#     6.16585423]
#  [ -0.3895914   -1.09579716  -2.53412147 ...   2.49204024   2.6441435
#     2.99646878]
#  [ -2.44901429  -3.399781    -5.06347587 ...   4.41399689   4.59814878
#     4.88049494]]

# %%
# 奇异值数量为原有的10%
get_image_feature(s, int(0.1*n))
# Out:
# [[ 2.71074320e+00 -1.14944589e+01 -1.58081166e+01 ...  1.51890457e+00
#   -1.11256071e-02 -3.38849110e+00]
#  [ 3.35091715e-01 -1.00355512e+01 -1.01453891e+01 ... -2.55178001e-02
#   -2.42044972e+00 -4.89721312e+00]
#  [-3.11352219e+00 -4.95525884e+00 -1.54185959e+00 ... -1.38339836e+00
#   -2.27145729e+00 -7.71807781e-01]
#  ...
#  [ 2.53147951e+00  4.76113354e+00  5.15396555e+00 ...  1.16439042e+00
#    3.69302627e+00  3.61983587e+00]
#  [-2.37013899e+00 -1.38123740e-01  9.22889059e-01 ...  8.63193342e-01
#    2.14051031e+00  9.46064586e-01]
#  [-5.28235484e+00 -7.75045971e-01 -3.40884964e-01 ... -6.99919426e-01
#   -9.12113809e-01 -2.12169577e+00]]

# %%
# 奇异值数量为原有的50%
get_image_feature(s, int(0.5*n))
# Out:
# [[ 0.01371256 -0.66351014 -0.84323253 ...  0.87320414  0.84655152
#   -0.50211348]
#  [ 0.6881102   0.02917545  0.64970189 ... -0.95746178 -0.37672147
#   -0.06911661]
#  [-0.27038316  1.14486981  0.97877533 ...  0.36931433 -0.24033184
#    0.72203362]
#  ...
#  [-0.59446354 -0.26716785 -0.03537505 ... -0.77986437 -0.5010349
#    0.84975702]
#  [ 0.71031334  0.26248537 -0.59801515 ... -0.3497076  -0.48857751
#    0.35271608]
#  [-0.28373477  0.39215854  0.6759417  ...  0.27962367  1.19939463
#   -0.65930378]]
